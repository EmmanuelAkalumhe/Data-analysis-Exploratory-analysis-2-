# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\eakal\Desktop\Groceries Dataset\countries.csv")

# %%
df
# Out:
#                                Country                    Region  \
# 0                          Afghanistan  Middle East/Central Asia
# 1                              Albania   Northern/Eastern Europe
# 2                              Algeria                    Africa
# 3                               Angola                    Africa
# 4                  Antigua and Barbuda             Latin America
# 5                            Argentina             Latin America
# 6                              Armenia  Middle East/Central Asia
# 7                                Aruba             Latin America
# 8                            Australia              Asia-Pacific
# 9                              Austria            European Union
# 10                          Azerbaijan  Middle East/Central Asia
# 11                             Bahamas             Latin America
# 12                             Bahrain  Middle East/Central Asia
# ...

# %%
df.shape
# Out:
# (188, 21)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=188, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population_(millions)', 'HDI', 'GDP_per_Capita',
#        'Cropland_Footprint', 'Grazing_Footprint', 'Forest_Footprint',
#        'Carbon_Footprint', 'Fish_Footprint', 'Total_Ecological_Footprint',
#        'Cropland', 'Grazing_Land', 'Forest_Land', 'Fishing_Water',
#        'Urban_Land', 'Total_Biocapacity', 'Biocapacity_Deficit_or_Reserve',
#        'Earths_Required', 'Countries_Required', 'Data_Quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                            object
# Region                             object
# Population_(millions)             float64
# HDI                               float64
# GDP_per_Capita                     object
# Cropland_Footprint                float64
# Grazing_Footprint                 float64
# Forest_Footprint                  float64
# Carbon_Footprint                  float64
# Fish_Footprint                    float64
# Total_Ecological_Footprint        float64
# Cropland                          float64
# Grazing_Land                      float64
# Forest_Land                       float64
# Fishing_Water                     float64
# Urban_Land                        float64
# Total_Biocapacity                 float64
# Biocapacity_Deficit_or_Reserve    float64
# Earths_Required                   float64
# Countries_Required                float64
# Data_Quality                       object
# dtype: object

# %%
df.head()
# Out:
#                Country                    Region  Population_(millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#   GDP_per_Capita  Cropland_Footprint  Grazing_Footprint  Forest_Footprint  \
# 0        $614.66                0.30               0.20              0.08
# 1      $4,534.37                0.78               0.22              0.25
# 2      $5,430.57                0.60               0.16              0.17
# 3      $4,665.91                0.33               0.15              0.12
# 4     $13,205.10                 NaN                NaN               NaN
#
# ...

# %%
df["Region"].head()
# Out:
# 0    Middle East/Central Asia
# 1     Northern/Eastern Europe
# 2                      Africa
# 3                      Africa
# 4               Latin America
# Name: Region, dtype: object

# %%
df.tail()
# Out:
#                        Country                    Region  \
# 183                   Viet Nam              Asia-Pacific
# 184  Wallis and Futuna Islands              Asia-Pacific
# 185                      Yemen  Middle East/Central Asia
# 186                     Zambia                    Africa
# 187                   Zimbabwe                    Africa
#
#      Population_(millions)   HDI GDP_per_Capita  Cropland_Footprint  \
# 183                  90.80  0.66      $1,532.31                0.50
# 184                   0.01   NaN            NaN                 NaN
# 185                  23.85  0.50      $1,302.30                0.34
# 186                  14.08  0.58      $1,740.64                0.19
# 187                  13.72  0.49        $865.91                0.20
#
#      Grazing_Footprint  Forest_Footprint  Carbon_Footprint  Fish_Footprint  \
# 183               0.01              0.19              0.79            0.05
# ...

# %%
df['Region'].tail()
# Out:
# 183                Asia-Pacific
# 184                Asia-Pacific
# 185    Middle East/Central Asia
# 186                      Africa
# 187                      Africa
# Name: Region, dtype: object

# %%
df['Population_(millions)'].unique()
# Out:
# array([2.98200e+01, 3.16000e+00, 3.84800e+01, 2.08200e+01, 9.00000e-02,
#        4.10900e+01, 2.97000e+00, 1.00000e-01, 2.30500e+01, 8.46000e+00,
#        9.31000e+00, 3.70000e-01, 1.32000e+00, 1.54700e+02, 2.80000e-01,
#        9.40000e+00, 1.10600e+01, 1.00500e+01, 6.00000e-02, 7.40000e-01,
#        1.05000e+01, 3.83000e+00, 2.00000e+00, 1.98660e+02, 3.00000e-02,
#        4.10000e-01, 7.28000e+00, 1.64600e+01, 9.85000e+00, 4.90000e-01,
#        1.48600e+01, 2.17000e+01, 3.48400e+01, 4.53000e+00, 1.24500e+01,
#        1.74600e+01, 1.40804e+03, 4.77000e+01, 7.20000e-01, 4.34000e+00,
#        6.57000e+01, 4.80000e+00, 1.98400e+01, 4.31000e+00, 1.12700e+01,
#        1.13000e+00, 1.06600e+01, 5.60000e+00, 8.60000e-01, 7.00000e-02,
#        1.02800e+01, 1.54900e+01, 8.07200e+01, 6.30000e+00, 6.13000e+00,
#        1.29000e+00, 9.17300e+01, 8.80000e-01, 5.41000e+00, 6.39800e+01,
#        2.40000e-01, 2.70000e-01, 1.63000e+00, 1.79000e+00, 4.36000e+00,
# ...

# %%
df.nunique()
# Out:
# Country                           188
# Region                              7
# Population_(millions)             179
# HDI                                58
# GDP_per_Capita                    173
# Cropland_Footprint                 87
# Grazing_Footprint                  62
# Forest_Footprint                   69
# Carbon_Footprint                  140
# Fish_Footprint                     43
# Total_Ecological_Footprint        156
# Cropland                           91
# Grazing_Land                       69
# Forest_Land                        99
# Fishing_Water                      73
# Urban_Land                         24
# Total_Biocapacity                 150
# Biocapacity_Deficit_or_Reserve    165
# Earths_Required                   150
# Countries_Required                162
# Data_Quality                        7
# dtype: int64

# %%
df.count()
# Out:
# Country                           188
# Region                            188
# Population_(millions)             188
# HDI                               172
# GDP_per_Capita                    173
# Cropland_Footprint                173
# Grazing_Footprint                 173
# Forest_Footprint                  173
# Carbon_Footprint                  173
# Fish_Footprint                    173
# Total_Ecological_Footprint        188
# Cropland                          173
# Grazing_Land                      173
# Forest_Land                       173
# Fishing_Water                     173
# Urban_Land                        173
# Total_Biocapacity                 188
# Biocapacity_Deficit_or_Reserve    188
# Earths_Required                   188
# Countries_Required                188
# Data_Quality                      188
# dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Africa                      52
# Latin America               39
# Asia-Pacific                33
# European Union              26
# Middle East/Central Asia    23
# Northern/Eastern Europe     12
# North America                3
# Name: Region, dtype: int64

# %%
df["Total_Biocapacity"].value_counts()
# Out:
# 1.24     4
# 0.50     3
# 0.32     3
# 1.30     3
# 0.59     3
# 0.56     3
# 0.62     3
# 1.51     3
# 0.35     2
# 0.60     2
# 0.54     2
# 1.17     2
# 0.53     2
# 1.78     2
# 0.70     2
# 0.88     2
# 9.55     2
# 0.58     2
# 1.08     2
# 1.26     2
# 0.94     2
# 3.07     2
# 1.27     2
# 0.71     2
# 1.25     2
# 0.19     2
# 0.45     2
# 2.27     2
# 0.34     2
# 0.29     1
#         ..
# 16.01    1
# 1.52     1
# 10.53    1
# 0.33     1
# 10.52    1
# 1.15     1
# 0.93     1
# 3.03     1
# 1.84     1
# 0.68     1
# 2.20     1
# 89.33    1
# 7.87     1
# 5.67     1
# 0.51     1
# 6.79     1
# 4.78     1
# 2.71     1
# 2.57     1
# 2.63     1
# 16.73    1
# 0.57     1
# 1.32     1
# 0.76     1
# 4.40     1
# 2.23     1
# 1.03     1
# 2.94     1
# 10.32    1
# 0.21     1
# Name: Total_Biocapacity, Length: 150, dtype: int64
